# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# Out:
# C:\Users\slaye\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
weather_data = pd.read_csv('weather_df.csv')
# Out:
# C:\Users\slaye\AppData\Local\Temp\ipykernel_22016\1021594493.py:1: DtypeWarning: Columns (23,24,29,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   weather_data = pd.read_csv('weather_df.csv')

# %%
weather_data.drop(columns = 'Unnamed: 0', axis = 1, inplace = True)

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 745013 entries, 0 to 745012
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   x                         745013 non-null  float64
#  1   y                         745013 non-null  float64
#  2   MAX_REL_HUMIDITY          152796 non-null  float64
#  3   TOTAL_SNOW_FLAG           229776 non-null  object
#  4   LOCAL_DAY                 745013 non-null  int64
#  5   DIRECTION_MAX_GUST        244206 non-null  float64
#  6   ID                        745013 non-null  object
#  7   MEAN_TEMPERATURE          510564 non-null  float64
#  8   MIN_REL_HUMIDITY          152977 non-null  float64
#  9   SNOW_ON_GROUND_FLAG       64505 non-null   object
#  10  TOTAL_PRECIPITATION_FLAG  181326 non-null  object
#  11  TOTAL_RAIN_FLAG           246989 non-null  object
#  12  HEATING_DEGREE_DAYS_FLAG  113094 non-null  object
# ...

# %%
weather_data.describe()
# Out:
#                    x              y  MAX_REL_HUMIDITY      LOCAL_DAY  \
# count  745013.000000  745013.000000     152796.000000  745013.000000
# mean      -71.918575      47.894368         91.087862      15.732997
# std         4.680196       3.420844          8.418284       8.800330
# min      -135.005833      45.033333         36.000000       1.000000
# 25%       -73.850000      45.766667         87.000000       8.000000
# 50%       -72.233333      46.666667         94.000000      16.000000
# 75%       -70.866667      48.598333         98.000000      23.000000
# max       -57.183333      68.223333        100.000000      31.000000
#
#        DIRECTION_MAX_GUST  MEAN_TEMPERATURE  MIN_REL_HUMIDITY  \
# count       244206.000000     510564.000000     152977.000000
# mean            15.112241          3.798367         59.948469
# std             12.811415         12.492358         17.800132
# min              0.000000        -43.600000          5.000000
# ...

# %%
len(weather_data.columns)
# Out:
# 36

# %%
wildfire_data = pd.read_csv('CANADA_WILDFIRES.csv')

# %%
wildfire_data.head()
# Out:
#    FID SRC_AGENCY  LATITUDE  LONGITUDE    REP_DATE  SIZE_HA CAUSE PROTZONE  \
# 0    0         BC    59.963   -128.172  1953-05-26      8.0     H
# 1    1         BC    59.318   -132.172  1950-06-22      8.0     L
# 2    2         BC    59.876   -131.922  1950-06-04  12949.9     H
# 3    3         BC    59.760   -132.808  1951-07-15    241.1     H
# 4    4         BC    59.434   -126.172  1952-06-12      1.2     H
#
#            ECOZ_NAME
# 0  Boreal Cordillera
# 1  Boreal Cordillera
# 2  Boreal Cordillera
# 3  Boreal Cordillera
# 4  Boreal Cordillera

# %%
wildfire_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423831 entries, 0 to 423830
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   FID         423831 non-null  int64
#  1   SRC_AGENCY  423831 non-null  object
#  2   LATITUDE    423831 non-null  float64
#  3   LONGITUDE   423831 non-null  float64
#  4   REP_DATE    420118 non-null  object
#  5   SIZE_HA     423831 non-null  float64
#  6   CAUSE       423590 non-null  object
#  7   PROTZONE    422821 non-null  object
#  8   ECOZ_NAME   423831 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 29.1+ MB

# %%
wildfire_data.describe()
# Out:
#                  FID       LATITUDE      LONGITUDE       SIZE_HA
# count  423831.000000  423831.000000  423831.000000  4.238310e+05
# mean   211915.000000      51.895936    -104.253547  3.162710e+02
# std    122349.615308       4.467770      20.412661  5.617050e+03
# min         0.000000       0.000000    -166.044000  0.000000e+00
# 25%    105957.500000      49.133700    -120.112350  1.000000e-01
# 50%    211915.000000      51.023000    -114.503000  1.000000e-01
# 75%    317872.500000      54.630289     -88.303603  1.000000e+00
# max    423830.000000      70.000000     116.188000  1.050000e+06

# %% [markdown]
# # We will only be interesting in wildfires in Quebec.

# %%
wildfire_data['SRC_AGENCY'].unique()
## Some of the national parks can be in Quebec. So we need to add them to the dataset.
# Out:
# array(['BC', 'AB', 'SK', 'MB', 'ON', 'QC', 'NL', 'NB', 'NS', 'YT', 'NT',
#        'PC-NA', 'PC-WB', 'PC-VU', 'PC-BA', 'PC-EI', 'PC-WP', 'PC-JA',
#        'PC-PA', 'PC-GL', 'PC-KO', 'PC-RE', 'PC-BT', 'PC-YO', 'PC-RM',
#        'PC-GF', 'PC-GR', 'PC-WL', 'PC-FR', 'PC-PU', 'PC-KG', 'PC-LM',
#        'PC-CB', 'PC-PE', 'PC-BP', 'PC-TI', 'PC-SL', 'PC-KE', 'PC-PP',
#        'PC-SY', 'PC-SE', 'PC-NC', 'PC-KL', 'PC-RE-GL', 'PC-GM', 'PC-PR',
#        'PC-TN', 'PC-GI', 'PC-FW', 'PC-FO', 'PC-GB', 'PC-LO', 'PC-RO',
#        'PC-FU', 'PC-MM', 'PC-TH'], dtype=object)

# %%
wildfire_QC_data = wildfire_data[wildfire_data['SRC_AGENCY']=='QC']
wildfire_QC_data.head()
# Out:
#            FID SRC_AGENCY  LATITUDE  LONGITUDE    REP_DATE  SIZE_HA CAUSE  \
# 328420  328420         QC   52.5747   -76.5213  2019-07-01    408.5     L
# 328421  328421         QC   52.5730   -76.5418  2019-07-01     34.5     L
# 328422  328422         QC   50.9285   -78.0518  2019-07-01    141.9     L
# 328423  328423         QC   52.6186   -76.6953  2018-06-28   3096.0     L
# 328424  328424         QC   51.1331   -77.9800  2018-06-28   3006.4     L
#
#         PROTZONE     ECOZ_NAME
# 328420  nordique  Hudson Plain
# 328421  nordique  Hudson Plain
# 328422  nordique  Hudson Plain
# 328423  Nordique  Hudson Plain
# 328424  Nordique  Hudson Plain

# %%
wildfire_QC_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43124 entries, 328420 to 371543
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FID         43124 non-null  int64
#  1   SRC_AGENCY  43124 non-null  object
#  2   LATITUDE    43124 non-null  float64
#  3   LONGITUDE   43124 non-null  float64
#  4   REP_DATE    43122 non-null  object
#  5   SIZE_HA     43124 non-null  float64
#  6   CAUSE       43124 non-null  object
#  7   PROTZONE    43119 non-null  object
#  8   ECOZ_NAME   43124 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 3.3+ MB

# %%
weather_data['PROVINCE_CODE'].unique()
# Out:
# array(['NT', 'QC'], dtype=object)

# %%
# Here we see that 1453 weather data is from a weather station located in Northwest Territories. We dont have to exclude it.
# There might be cases where a fire occured in the border of Quebec and Northwest Territories so we may need to use weather
# data from a weather station in Northwest territories. 
weather_data[weather_data['PROVINCE_CODE']=='NT'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1453 entries, 0 to 1452
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   x                         1453 non-null   float64
#  1   y                         1453 non-null   float64
#  2   MAX_REL_HUMIDITY          1092 non-null   float64
#  3   TOTAL_SNOW_FLAG           53 non-null     object
#  4   LOCAL_DAY                 1453 non-null   int64
#  5   DIRECTION_MAX_GUST        397 non-null    float64
#  6   ID                        1453 non-null   object
#  7   MEAN_TEMPERATURE          1433 non-null   float64
#  8   MIN_REL_HUMIDITY          1092 non-null   float64
#  9   SNOW_ON_GROUND_FLAG       28 non-null     object
#  10  TOTAL_PRECIPITATION_FLAG  1214 non-null   object
#  11  TOTAL_RAIN_FLAG           34 non-null     object
#  12  HEATING_DEGREE_DAYS_FLAG  18 non-null     object
# ...

# %%
weather_data[weather_data['PROVINCE_CODE']== 'QC'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 743560 entries, 1453 to 745012
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   x                         743560 non-null  float64
#  1   y                         743560 non-null  float64
#  2   MAX_REL_HUMIDITY          151704 non-null  float64
#  3   TOTAL_SNOW_FLAG           229723 non-null  object
#  4   LOCAL_DAY                 743560 non-null  int64
#  5   DIRECTION_MAX_GUST        243809 non-null  float64
#  6   ID                        743560 non-null  object
#  7   MEAN_TEMPERATURE          509131 non-null  float64
#  8   MIN_REL_HUMIDITY          151885 non-null  float64
#  9   SNOW_ON_GROUND_FLAG       64477 non-null   object
#  10  TOTAL_PRECIPITATION_FLAG  180112 non-null  object
#  11  TOTAL_RAIN_FLAG           246955 non-null  object
#  12  HEATING_DEGREE_DAYS_FLAG  113076 non-null  object
# ...

# %%
weather_data.head()
# Out:
#             x          y  MAX_REL_HUMIDITY TOTAL_SNOW_FLAG  LOCAL_DAY  \
# 0 -135.005833  68.223333               NaN             NaN          2
# 1 -135.005833  68.223333               NaN             NaN          4
# 2 -135.005833  68.223333               NaN             NaN          5
# 3 -135.005833  68.223333               NaN             NaN          6
# 4 -135.005833  68.223333               NaN             NaN          7
#
#    DIRECTION_MAX_GUST                ID  MEAN_TEMPERATURE  MIN_REL_HUMIDITY  \
# 0                 NaN  2200100.2012.8.2              19.2               NaN
# 1                 NaN  2200100.2012.8.4              16.2               NaN
# 2                 NaN  2200100.2012.8.5              16.3               NaN
# 3                 NaN  2200100.2012.8.6              17.3               NaN
# 4                 NaN  2200100.2012.8.7              13.8               NaN
#
#   SNOW_ON_GROUND_FLAG  ... COOLING_DEGREE_DAYS_FLAG LOCAL_YEAR  \
# ...

# %%
from datetime import datetime, date

# %%
wildfire_data['REP_DATE'] = pd.to_datetime(wildfire_data['REP_DATE'])

# %% [markdown]
# ### We will explore the data by year.

# %%
all_fire_years = pd.to_datetime(wildfire_QC_data['REP_DATE']).apply(lambda time: time.year)

# %%
all_fire_month = pd.to_datetime(wildfire_QC_data['REP_DATE']).apply(lambda time: time.month)

# %%
all_fire_month.unique()
# Out:
# array([ 7.,  6.,  5.,  9., 10.,  8., 11.,  4., nan,  3., 12.])

# %%
len(all_fire_years.unique())
# Out:
# 64

# %%
all_fire_years.unique()
# Out:
# array([2019., 2018., 2017., 1962., 1968., 1970., 1959., 1960., 1961.,
#        1963., 1965., 1969., 1972., 1964., 1967., 1966., 1973., 1974.,
#        1975., 1971., 1976.,   nan, 1978., 1977., 1979., 1980., 1981.,
#        1982., 1983., 1984., 1985., 1986., 1987., 1988., 1989., 1990.,
#        1991., 1992., 1993., 1994., 1995., 1996., 1997., 1998., 1999.,
#        2000., 2001., 2003., 2002., 2005., 2006., 2007., 2004., 2016.,
#        2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015., 2020.,
#        2021.])

# %% [markdown]
# ### There are only 2 fires that missing date information. However, notice that both of these fires are not caused by lightning. So they will be eliminated in following steps when we only choose lightning caused fires.

# %%
wildfire_QC_data[wildfire_QC_data['REP_DATE'].isna()]
# Out:
#            FID SRC_AGENCY  LATITUDE  LONGITUDE REP_DATE  SIZE_HA CAUSE  \
# 331162  331162         QC   47.7305  -70.26170      NaN    257.0     U
# 336822  336822         QC   46.2500  -74.83333      NaN      0.0     H
#
#          PROTZONE           ECOZ_NAME
# 331162  Intensive  Boreal Shield East
# 336822  Intensive  Boreal Shield East

# %%
all_fire_years.max()
# Out:
# 2021.0

# %%
all_fire_years.min()
# Out:
# 1959.0

# %%
all_weather_years = pd.to_datetime(weather_data['LOCAL_DATE']).apply(lambda time : time.year)

# %%
all_weather_years.max()
# Out:
# 2021

# %%
all_weather_years.min()
# Out:
# 2011

# %% [markdown]
# # Weather dataset is between 2011-2021 whereas wildfire data set is from 1950 to 2021.

# %%
pd.to_datetime(wildfire_QC_data[wildfire_QC_data['REP_DATE']>'2010-12-31']['REP_DATE']).apply(lambda x : x.year).unique()
# Out:
# array([2019, 2018, 2017, 2016, 2011, 2012, 2013, 2014, 2015, 2020, 2021],
#       dtype=int64)

# %%
wildfire_QC_2011=wildfire_QC_data[wildfire_QC_data['REP_DATE']>'2010-12-31']
wildfire_QC_2011
# Out:
#            FID SRC_AGENCY  LATITUDE  LONGITUDE    REP_DATE  SIZE_HA CAUSE  \
# 328420  328420         QC   52.5747   -76.5213  2019-07-01    408.5     L
# 328421  328421         QC   52.5730   -76.5418  2019-07-01     34.5     L
# 328422  328422         QC   50.9285   -78.0518  2019-07-01    141.9     L
# 328423  328423         QC   52.6186   -76.6953  2018-06-28   3096.0     L
# 328424  328424         QC   51.1331   -77.9800  2018-06-28   3006.4     L
# ...        ...        ...       ...        ...         ...      ...   ...
# 371539  371539         QC   45.4606   -72.1554  2021-10-28      0.0     H
# 371540  371540         QC   45.9512   -75.8547  2021-11-09      2.0     H
# 371541  371541         QC   45.9812   -74.2104  2021-11-11      0.0     H
# 371542  371542         QC   45.3931   -72.1209  2021-11-10      0.0     H
# 371543  371543         QC   45.0850   -72.5975  2021-11-12      0.0     H
#
#          PROTZONE           ECOZ_NAME
# 328420   nordique        Hudson Plain
# ...

# %%
wildfire_QC_2011_copy = wildfire_QC_2011.copy()
wildfire_QC_2011_copy['Year'] = pd.to_datetime(wildfire_QC_2011_copy['REP_DATE']).apply(lambda x : x.year)

# %%
byYear = wildfire_QC_2011_copy.groupby('Year').count()

# %%
for year in byYear.index:
    byYear['SIZE_HA'].loc[year] = wildfire_QC_2011_copy[wildfire_QC_2011_copy['Year']==year]['SIZE_HA'].sum()
byYear
# Out:
#       FID  SRC_AGENCY  LATITUDE  LONGITUDE  REP_DATE    SIZE_HA  CAUSE  \
# Year
# 2011  329         329       329        329       329    12397.5    329
# 2012  795         795       795        795       795    64043.1    795
# 2013  515         515       515        515       515  1872842.2    515
# 2014  292         292       292        292       292    63720.7    292
# 2015  384         384       384        384       384     5379.6    384
# 2016  602         602       602        602       602    33370.8    602
# 2017  317         317       317        317       317    38391.9    317
# 2018  592         592       592        592       592    86260.7    592
# 2019  357         357       357        357       357     9604.0    357
# 2020  707         707       707        707       707    59986.1    707
# 2021  624         624       624        624       624    49483.1    624
#
#       PROTZONE  ECOZ_NAME
# Year
# 2011       329        329
# 2012       795        795
# ...

# %%
byYear['SIZE_HA_L'] = 0
byYear['SIZE_HA_H'] = 0
for year in byYear.index:
    byYear['SIZE_HA_L'].loc[year] = wildfire_QC_2011_copy[(wildfire_QC_2011['CAUSE'] == 'L') & 
                                                          (wildfire_QC_2011_copy['Year']==year)]['SIZE_HA'].sum()
    byYear['SIZE_HA_H'].loc[year] = wildfire_QC_2011_copy[(wildfire_QC_2011['CAUSE'] == 'H') & 
                                                          (wildfire_QC_2011_copy['Year']==year)]['SIZE_HA'].sum()
byYear
# Out:
# C:\Users\slaye\AppData\Local\Temp\ipykernel_22016\2543145719.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   byYear['SIZE_HA_L'].loc[year] = wildfire_QC_2011_copy[(wildfire_QC_2011['CAUSE'] == 'L') &
# C:\Users\slaye\AppData\Local\Temp\ipykernel_22016\2543145719.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   byYear['SIZE_HA_H'].loc[year] = wildfire_QC_2011_copy[(wildfire_QC_2011['CAUSE'] == 'H') &
#       FID  SRC_AGENCY  LATITUDE  LONGITUDE  REP_DATE    SIZE_HA  CAUSE  \
# Year
# 2011  329         329       329        329       329    12397.5    329
# ...

# %%
# Size of all fires by year. 
ax = sns.barplot(data = byYear, x=byYear.index, y= byYear['SIZE_HA'])
ax.set_title('Size of all fires by year')
ax.set(xlabel='Year', ylabel='Hectare')
plt.savefig('sizebyyear.jpg',bbox_inches = 'tight',pad_inches = 0.1)
plt.show()

# %%
#Size of lightning caused fires by year.
ax = sns.barplot(data = byYear, x=byYear.index, y= byYear['SIZE_HA_L'])
ax.set_title('Size of fires caused by lightning by year')
ax.set(xlabel='Year', ylabel='Hectare')
plt.savefig('sizelightbyyear.jpg',bbox_inches = 'tight',pad_inches = 0.1)
plt.show()

# %%
#Size of human caused fires by year.
ax = sns.barplot(data = byYear, x=byYear.index, y= byYear['SIZE_HA_H'])
ax.set_title('Size of fires caused by human by year')
ax.set(xlabel='Year', ylabel='Hectare')
plt.savefig('sizehumanbyyear.jpg',bbox_inches = 'tight',pad_inches = 0.1)
plt.show()

# %%
wildfire_QC_2011_copy['CAUSE'].value_counts()
# Out:
# H    4103
# L    1411
# Name: CAUSE, dtype: int64

# %%
print('Total size of fires caused by lightning is', byYear['SIZE_HA_L'].sum(), 
      'and the number of fires caused by lightning is 1411', 
      'whereas total size of fires caused by human is', 
      byYear['SIZE_HA_H'].sum(), 
      'and the number fires caused by human is 4103')

print('So the average size of a fire caused by human is', byYear['SIZE_HA_H'].sum()/4103, 
      'whereas the average size of a fire caused by lightning is', byYear['SIZE_HA_L'].sum()/1411 )
# Out:
# Total size of fires caused by lightning is 2165329.1 and the number of fires caused by lightning is 1411 whereas total size of fires caused by human is 130150.59999999999 and the number fires caused by human is 4103
# So the average size of a fire caused by human is 31.720838410918837 whereas the average size of a fire caused by lightning is 1534.6060240963857

# %% [markdown]
# ### This tells us that the fires caused by lightnings are likely to burn 48.5 times bigger than fires caused by humans. So fires caused by lightning are much more dangerous for nature, animals and human than fires caused by humans. This also makes firefighters job more difficult if one have to put out a fire caused by lightning.

# %%
l=[]
for year in byYear.index:
    l.append(byYear.loc[year]['SIZE_HA']/byYear.loc[year]['CAUSE'])
    print('In', year,'average size of a fire whatever the cause is', byYear.loc[year]['SIZE_HA']/byYear.loc[year]['CAUSE'])

print('Average size of a fire between 2011-2021 whatever the cause is', sum(l)/len(l))
# Out:
# In 2011 average size of a fire whatever the cause is 37.6823708206687
# In 2012 average size of a fire whatever the cause is 80.55735849056603
# In 2013 average size of a fire whatever the cause is 3636.586796116505
# In 2014 average size of a fire whatever the cause is 218.22157534246574
# In 2015 average size of a fire whatever the cause is 14.009374999999999
# In 2016 average size of a fire whatever the cause is 55.43322259136212
# In 2017 average size of a fire whatever the cause is 121.11009463722395
# In 2018 average size of a fire whatever the cause is 145.7106418918919
# In 2019 average size of a fire whatever the cause is 26.901960784313726
# In 2020 average size of a fire whatever the cause is 84.84596888260253
# In 2021 average size of a fire whatever the cause is 79.29983974358977
# Average size of a fire between 2011-2021 whatever the cause is 409.12356402738084

# %%
human_cause = wildfire_QC_2011_copy[wildfire_QC_2011_copy['CAUSE']=='H']
human_cause.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4103 entries, 328437 to 371543
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FID         4103 non-null   int64
#  1   SRC_AGENCY  4103 non-null   object
#  2   LATITUDE    4103 non-null   float64
#  3   LONGITUDE   4103 non-null   float64
#  4   REP_DATE    4103 non-null   object
#  5   SIZE_HA     4103 non-null   float64
#  6   CAUSE       4103 non-null   object
#  7   PROTZONE    4103 non-null   object
#  8   ECOZ_NAME   4103 non-null   object
#  9   Year        4103 non-null   int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 352.6+ KB

# %%
human_cause['SIZE_HA'].max()
# Out:
# 50891.5

# %%
human_cause['SIZE_HA'].mean()
# Out:
# 31.720838410919207

# %%
byYear_human=human_cause.groupby('Year').mean()
byYear_human
# Out:
#                 FID   LATITUDE  LONGITUDE    SIZE_HA
# Year
# 2011  368029.316017  47.743508 -75.050349   9.838528
# 2012  368272.243762  47.239921 -74.272629  47.565643
# 2013  367598.549451  47.339660 -72.293154  47.062363
# 2014  368051.446429  47.935209 -72.968560  37.573661
# 2015  368066.961538  46.974498 -73.390098   4.320414
# 2016  367951.102088  46.862115 -73.514808   0.775870
# 2017  330360.641026  47.702858 -72.698802   7.233761
# 2018  330791.500000  47.334534 -72.807435  39.628392
# 2019  331029.336957  47.384120 -73.591362  18.431522
# 2020  370520.821053  46.809960 -72.803350  91.384211
# 2021  371212.992248  47.065193 -73.411297   2.157752

# %%
lightning_cause = wildfire_QC_2011_copy[wildfire_QC_2011_copy['CAUSE']=='L']
byYear_lightning = wildfire_QC_2011_copy.groupby('Year').mean()
byYear_lightning
# Out:
#                 FID   LATITUDE  LONGITUDE      SIZE_HA
# Year
# 2011  368005.085106  48.096434 -74.800566    37.682371
# 2012  368270.594969  47.464358 -74.800124    80.557358
# 2013  367438.522330  48.410974 -72.427963  3636.586796
# 2014  367896.356164  48.527578 -72.568820   218.221575
# 2015  368045.255208  47.261656 -73.620328    14.009375
# 2016  367838.367110  48.020958 -73.061073    55.433223
# 2017  330287.050473  48.168221 -72.729003   121.110095
# 2018  330569.229730  47.995155 -73.299060   145.710642
# 2019  330864.829132  47.800164 -73.353481    26.901961
# 2020  370566.000000  47.344686 -72.407549    84.845969
# 2021  371231.500000  47.446104 -73.528300    79.299840

# %%
import seaborn as sns
# Out:
# C:\Users\slaye\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
for year in byYear.index:
    byYear['CAUSE'].loc[year] = len(wildfire_QC_2011_copy[wildfire_QC_2011_copy['Year']==year])
byYear
# Out:
# C:\Users\slaye\AppData\Local\Temp\ipykernel_11332\3460766253.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   byYear['CAUSE'].loc[year] = len(wildfire_QC_2011_copy[wildfire_QC_2011_copy['Year']==year])
#       FID  SRC_AGENCY  LATITUDE  LONGITUDE  REP_DATE    SIZE_HA  CAUSE  \
# Year
# 2011  329         329       329        329       329    12397.5    329
# 2012  795         795       795        795       795    64043.1    795
# 2013  515         515       515        515       515  1872842.2    515
# 2014  292         292       292        292       292    63720.7    292
# 2015  384         384       384        384       384     5379.6    384
# 2016  602         602       602        602       602    33370.8    602
# 2017  317         317       317        317       317    38391.9    317
# ...

# %%
plt.figure(figsize=(10,6))

plt.plot(byYear.index, byYear['CAUSE'])
plt.xlabel('Year', fontsize = 20)
plt.ylabel('Number of wildfires', fontsize = 20)
plt.title('Total number of wildfires by year')
plt.savefig('numberfirebyyear.jpg')
plt.show()

# %%
#Total number of wildfires with seaborn. 
ax = sns.barplot(data = byYear, x=byYear.index, y='CAUSE', color = 'r', palette='viridis')
ax.bar_label(ax.containers[0], fontsize=70);
sns.set(rc={'figure.figsize':(70,45)})
ax.tick_params(axis='both', which='major', labelsize=60, width=2.5, length=10)
plt.xlabel('Year',fontsize = 70)
plt.ylabel('Number of Wildfires', fontsize=70)
plt.savefig('numberoffiresperyear.jpg')

# %% [markdown]
# ### Now we create a interactive map that shows wildfires caused by lightning and weather stations. To see this please open html file in the file.

# %%
weather_data_copy = weather_data.copy()

# %%
weather_data_copy['Location'] = weather_data_copy['x'].astype(str) + ',' + weather_data_copy['y'].astype(str)

# %%
weather_data_copy['Location']
# Out:
# 0         -135.00583333333333,68.22333333333333
# 1         -135.00583333333333,68.22333333333333
# 2         -135.00583333333333,68.22333333333333
# 3         -135.00583333333333,68.22333333333333
# 4         -135.00583333333333,68.22333333333333
#                           ...
# 745008                 -76.05,46.06666666666667
# 745009                 -76.05,46.06666666666667
# 745010                 -76.05,46.06666666666667
# 745011                 -76.05,46.06666666666667
# 745012                 -76.05,46.06666666666667
# Name: Location, Length: 745013, dtype: object

# %%
import folium
from folium.plugins import MarkerCluster

# %%
coordinate_list = []
for x in weather_data_copy['Location']:
    splitted_x = [float(x.split(',')[1]),float(x.split(',')[0])]
    coordinate_list.append(splitted_x)

# %%
QC_coords = [46.829853, -71.254028]

#Create the map
my_map = folium.Map(location = QC_coords, zoom_start = 5)

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
unique_coords = []
for coord in coordinate_list:
    if coord not in unique_coords:
        unique_coords.append(coord)

# %%
for i in unique_coords:
    folium.Marker(i, popup = 'Weather Station', icon = folium.Icon(icon = "cloud", color = "blue")).add_to(my_map)

    
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
wildfire_QC_2011_L=wildfire_QC_2011_copy[wildfire_QC_2011_copy['CAUSE']=='L']
wildfire_QC_2011_L['Location'] = wildfire_QC_2011_L['LATITUDE'].astype(str)+','+wildfire_QC_2011_L['LONGITUDE'].astype(str)
wildfire_QC_2011_L.head()
# Out:
# C:\Users\slaye\AppData\Local\Temp\ipykernel_22016\2937373378.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wildfire_QC_2011_L['Location'] = wildfire_QC_2011_L['LATITUDE'].astype(str)+','+wildfire_QC_2011_L['LONGITUDE'].astype(str)
#            FID SRC_AGENCY  LATITUDE  LONGITUDE    REP_DATE  SIZE_HA CAUSE  \
# 328420  328420         QC   52.5747   -76.5213  2019-07-01    408.5     L
# 328421  328421         QC   52.5730   -76.5418  2019-07-01     34.5     L
# 328422  328422         QC   50.9285   -78.0518  2019-07-01    141.9     L
# 328423  328423         QC   52.6186   -76.6953  2018-06-28   3096.0     L
# 328424  328424         QC   51.1331   -77.9800  2018-06-28   3006.4     L
#
# ...

# %%
wildfire_QC_2011_L['Location'].isna().value_counts()
# Out:
# False    1411
# Name: Location, dtype: int64

# %%
coordinate_list2 = []
for x in wildfire_QC_2011_L['Location']:
    splitted_x = [float(x.split(',')[0]),float(x.split(',')[1])]
    coordinate_list2.append(splitted_x)
unique_coords2 = []
for coord in coordinate_list2:
    if coord not in unique_coords2:
        unique_coords2.append(coord)

# %%
len(unique_coords2)
# Out:
# 1409

# %%
for i in unique_coords2:
    folium.Marker(i, popup = 'Wildfire',icon = folium.Icon(color = "red")).add_to(my_map)
my_map
##Map of weather stations and wildfires that are between 2011-2021 and whose cause is lightning.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
my_map.save('QuebecFiresWeatherStations.html')

# %% [markdown]
# ### Now we explore weather data.

# %%
byYearWeather = weather_data_copy.groupby('LOCAL_YEAR').count()
for year in byYearWeather.index:
    byYearWeather['TOTAL_RAIN'].loc[year] = weather_data_copy[weather_data_copy['LOCAL_YEAR']==year]['TOTAL_RAIN'].sum()
byYearWeather
# Out:
#                 x      y  MAX_REL_HUMIDITY  TOTAL_SNOW_FLAG  LOCAL_DAY  \
# LOCAL_YEAR
# 2011        54943  54943             13411            19017      54943
# 2012        73199  73199             17128            27670      73199
# 2013        72794  72794             15998            28031      72794
# 2014        73531  73531               478            28493      73531
# 2015        73235  73235               365            28910      73235
# 2016        70625  70625               366            28864      70625
# 2017        63525  63525               384            27921      63525
# 2018        64334  64334             11614            19789      64334
# 2019        67032  67032             32031             7288      67032
# 2020        69409  69409             30612             7384      69409
# 2021        62386  62386             30409             6409      62386
#
#             DIRECTION_MAX_GUST     ID  MEAN_TEMPERATURE  MIN_REL_HUMIDITY  \
# LOCAL_YEAR
# ...

# %%
#Total rain by year in Quebec between 2011 and 2021.
plt.figure(figsize=(10,6))
plt.plot(byYearWeather.index, byYearWeather['TOTAL_RAIN'])
plt.xlabel('Year', fontsize = 20)
plt.ylabel('Total Rain', fontsize = 20)
plt.savefig('rainperyear.jpg')
plt.show()

# %%
for year in byYearWeather.index:
    byYearWeather['MEAN_TEMPERATURE'].loc[year] = weather_data_copy[weather_data_copy['LOCAL_YEAR']==year]['MEAN_TEMPERATURE'].mean()
# Out:
# C:\Users\slaye\AppData\Local\Temp\ipykernel_22016\669747435.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   byYearWeather['MEAN_TEMPERATURE'].loc[year] = weather_data_copy[weather_data_copy['LOCAL_YEAR']==year]['MEAN_TEMPERATURE'].mean()

# %%
#Mean Temperature by year in Quebec between 2011 and 2021. 
plt.figure(figsize=(10,6))
plt.plot(byYearWeather.index, byYearWeather['MEAN_TEMPERATURE'])
plt.xlabel('Year', fontsize = 20)
plt.ylabel('Mean Temperature', fontsize = 20)
plt.savefig('meantempperyear.jpg')
plt.show()

# %%
for year in byYearWeather.index:
    byYearWeather['MAX_TEMPERATURE'].loc[year] = weather_data_copy[weather_data_copy['LOCAL_YEAR']==year]['MAX_TEMPERATURE'].mean()
# Out:
# C:\Users\slaye\AppData\Local\Temp\ipykernel_22016\2366390684.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   byYearWeather['MAX_TEMPERATURE'].loc[year] = weather_data_copy[weather_data_copy['LOCAL_YEAR']==year]['MAX_TEMPERATURE'].mean()

# %%
#Max Temperature by year in Quebec between 2011 and 2021. 
plt.figure(figsize=(10,6))
plt.plot(byYearWeather.index, byYearWeather['MAX_TEMPERATURE'])
plt.xlabel('Year', fontsize = 20)
plt.ylabel('Max Temperature', fontsize = 20)
plt.savefig('maxtempperyear.jpg')
plt.show()

# %%
for year in byYearWeather.index:
    byYearWeather['MIN_TEMPERATURE'].loc[year] = weather_data_copy[weather_data_copy['LOCAL_YEAR']==year]['MIN_TEMPERATURE'].mean()
# Out:
# C:\Users\slaye\AppData\Local\Temp\ipykernel_22016\1779895107.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   byYearWeather['MIN_TEMPERATURE'].loc[year] = weather_data_copy[weather_data_copy['LOCAL_YEAR']==year]['MIN_TEMPERATURE'].mean()

# %%
#Min Temperature by year in Quebec between 2011 and 2021. 
plt.figure(figsize=(10,6))
plt.plot(byYearWeather.index, byYearWeather['MIN_TEMPERATURE'])
plt.xlabel('Year', fontsize = 20)
plt.ylabel('Min Temperature', fontsize = 20)
plt.savefig('mintempperyear.jpg')
plt.show()

# %%
for year in byYearWeather.index:
    byYearWeather['MIN_REL_HUMIDITY'].loc[year] = weather_data_copy[weather_data_copy['LOCAL_YEAR']==year]['MIN_REL_HUMIDITY'].mean()
# Out:
# C:\Users\slaye\AppData\Local\Temp\ipykernel_22016\1104489090.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   byYearWeather['MIN_REL_HUMIDITY'].loc[year] = weather_data_copy[weather_data_copy['LOCAL_YEAR']==year]['MIN_REL_HUMIDITY'].mean()

# %%
#Minimum relative humidity by year in Quebec between 2011 and 2021. 
plt.figure(figsize=(10,6))
plt.plot(byYearWeather.index, byYearWeather['MIN_REL_HUMIDITY'])
plt.xlabel('Year', fontsize = 20)
plt.ylabel('Minimum Relative Humidity', fontsize = 20)
plt.savefig('minrelhumidity.jpg')
plt.show()

# %%
#Maximum relative humidity by year in Quebec between 2011 and 2021. 
plt.figure(figsize=(10,6))
plt.plot(byYearWeather.index, byYearWeather['MAX_REL_HUMIDITY'])
plt.xlabel('Year', fontsize = 20)
plt.ylabel('Maximum Relative Humidity', fontsize = 20)
plt.savefig('maxrelhumidity.jpg')
plt.show()

# %%
weather_data_copy['MEAN_TEMPERATURE'].max()
# Out:
# 30.1

# %%
weather_data_copy['MEAN_TEMPERATURE'].min()
# Out:
# -43.6

# %%
weather_data_copy['TOTAL_RAIN'].max()
# Out:
# 214.0

# %%
weather_data_copy['TOTAL_RAIN'].min()
# Out:
# 0.0

# %%
weather_data_copy['TOTAL_RAIN'].mean()
# Out:
# 2.291854231982976

# %%
wildfire_QC_2011_copy['Location'] = wildfire_QC_2011_copy['LATITUDE'].astype(str)+','+wildfire_QC_2011_copy['LONGITUDE'].astype(str)

# %%
duplicated_fires= wildfire_QC_2011_copy[wildfire_QC_2011_copy['Location'].duplicated()==True]
duplicated_fires
# Out:
#            FID SRC_AGENCY  LATITUDE  LONGITUDE    REP_DATE  SIZE_HA CAUSE  \
# 331153  331153         QC   47.0099   -71.3424  2017-07-31      0.0     H
# 364611  364611         QC   47.9825   -69.3053  2013-05-15      0.3     H
# 365809  365809         QC   45.6114   -72.4578  2013-05-02      0.1     H
# 365865  365865         QC   45.7914   -72.0175  2016-04-30      0.1     H
# 367396  367396         QC   50.0369   -66.8664  2014-07-01      0.0     H
# 367852  367852         QC   48.1831   -77.7178  2012-07-14      0.0     H
# 367857  367857         QC   48.0658   -79.4181  2012-07-12      0.0     L
# 367862  367862         QC   48.0747   -77.7083  2012-09-01      0.0     H
# 367944  367944         QC   48.0747   -77.7083  2016-07-20      0.4     H
# 368012  368012         QC   48.7519   -69.1367  2014-08-10      0.0     H
# 368217  368217         QC   48.5433   -71.8050  2012-07-24      0.0     H
# 368530  368530         QC   47.0100   -71.3428  2016-10-12      0.0     H
# ...

# %%
for location in duplicated_fires['Location']:
    loc_date_list = []
    loc_date_list.append(location)
    for date in wildfire_QC_2011_copy[wildfire_QC_2011_copy['Location']==location]['REP_DATE']:
        loc_date_list.append(date)
    print(loc_date_list)
# Out:
# ['47.0099,-71.3424', '2019-08-16', '2017-07-31']
# ['47.9825,-69.3053', '2013-05-04', '2013-05-15']
# ['45.6114,-72.4578', '2013-05-02', '2013-05-02']
# ['45.7914,-72.0175', '2016-04-29', '2016-04-30']
# ['50.0369,-66.8664', '2013-07-08', '2014-07-01']
# ['48.1831,-77.71779999999998', '2012-07-12', '2012-07-14']
# ['48.0658,-79.41809999999998', '2012-07-14', '2012-07-12']
# ['48.0747,-77.70829999999998', '2011-05-11', '2012-09-01', '2016-07-20']
# ['48.0747,-77.70829999999998', '2011-05-11', '2012-09-01', '2016-07-20']
# ['48.7519,-69.1367', '2013-08-22', '2014-08-10']
# ['48.5433,-71.805', '2012-07-21', '2012-07-24']
# ['47.01,-71.3428', '2016-10-12', '2016-10-12']
# ['47.2997,-74.0383', '2014-08-10', '2014-08-12']
# ['46.6856,-73.91169999999998', '2011-06-01', '2015-05-19']
# ['46.0828,-73.75', '2012-04-13', '2012-04-14']
# ['46.0378,-74.2972', '2012-09-12', '2013-07-25']
# ['45.855,-74.5892', '2011-07-25', '2016-08-05', '2016-08-09']
# ...

# %%
weather_data_copy.duplicated().value_counts()
# Out:
# False    739786
# True       5227
# dtype: int64

# %%
##We only have 2 weather stations who has duplicated datas and they are far away from each other.
weather_data_copy[weather_data_copy.duplicated()==True]['Location'].unique()
# Out:
# array(['-68.2075,48.60888888888889',
#        '-77.78277777777778,48.053333333333335'], dtype=object)

# %%
len(weather_data_copy[weather_data_copy.duplicated()==True]['LOCAL_DATE'].unique())
# Out:
# 3648

# %%
weather_data_copy['DIRECTION_MAX_GUST_FLAG'].value_counts()
# Out:
# M    39803
# E     3294
# S        1
# Name: DIRECTION_MAX_GUST_FLAG, dtype: int64

# %%
column_list = ['MAX_REL_HUMIDITY','DIRECTION_MAX_GUST','MEAN_TEMPERATURE','MIN_REL_HUMIDITY','TOTAL_RAIN','SPEED_MAX_GUST',
              'TOTAL_PRECIPITATION','MAX_TEMPERATURE','TOTAL_SNOW','MIN_TEMPERATURE']
for feature in column_list:
    print("Missing values for the feature", feature, "is:", weather_data_copy[feature].isna().value_counts(), sep = '\n\n')
    print()
# Out:
# Missing values for the feature
#
# MAX_REL_HUMIDITY
#
# is:
#
# True     592217
# False    152796
# Name: MAX_REL_HUMIDITY, dtype: int64
#
# Missing values for the feature
#
# DIRECTION_MAX_GUST
#
# is:
#
# True     500807
# False    244206
# Name: DIRECTION_MAX_GUST, dtype: int64
#
# Missing values for the feature
#
# MEAN_TEMPERATURE
#
# is:
#
# False    510564
# True     234449
# Name: MEAN_TEMPERATURE, dtype: int64
#
# Missing values for the feature
#
# MIN_REL_HUMIDITY
#
# is:
#
# True     592036
# False    152977
# Name: MIN_REL_HUMIDITY, dtype: int64
#
# Missing values for the feature
#
# TOTAL_RAIN
#
# is:
#
# False    384666
# True     360347
# Name: TOTAL_RAIN, dtype: int64
#
# Missing values for the feature
#
# SPEED_MAX_GUST
#
# is:
#
# True     497708
# False    247305
# Name: SPEED_MAX_GUST, dtype: int64
#
# Missing values for the feature
#
# TOTAL_PRECIPITATION
#
# is:
#
# False    560510
# True     184503
# Name: TOTAL_PRECIPITATION, dtype: int64
#
# ...

# %%
station_names = weather_data_copy['STATION_NAME'].unique()

station_names
# Out:
# array(['AKLAVIK A', 'BONNARD 1', 'AMQUI', 'ARTHABASKA', 'AUTEUIL',
#        'BEAUSEJOUR', 'BONSECOURS', 'BROME', 'BROMPTONVILLE', 'AUPALUK A',
#        'AKULIVIK A', 'ANGERS', 'ARUNDEL', 'CAP DES ROSIERS',
#        'BAGOTVILLE A', 'BARRAGE TEMISCAMINGUE', 'CAP-TOURMENTE',
#        'CAP-ROUGE', 'CHAMOUCHOUANE', 'CHARLEVOIX (MRC)', 'CHAPAIS',
#        'CHAMPLAIN', 'COTEAU DU LAC', 'CHIBOUGAMAU CHAPAIS A', 'COATICOOK',
#        'DANVILLE', 'CAUSAPSCAL AIRPORT', 'CHIBOUGAMAU-CHAPAIS',
#        'CHARTERIS', 'CHELSEA', 'CHENEVILLE', 'CAPE WHITTLE',
#        'CHATEAU RICHER', 'CAUSAPSCAL', 'CHUTE-DES-PASSES', 'CHEVERY',
#        'CAP-MADELEINE', "CAP-D'ESPOIR", 'DESCHAMBAULT', 'GRANBY',
#        'GASPE A', 'DONNACONA 2', 'EASTMAIN RIVER A', 'DRUMMONDVILLE',
#        'FARNHAM', 'FLEURY', 'FORTIERVILLE', 'GEORGEVILLE',
#        'GRANDES-BERGERONNES', 'GODBOUT', 'GRANDES BERGERONNES',
#        'GRANDE ANSE', 'ILES DE LA MADELEINE', 'ILE AUX PERROQUETS',
# ...

# %% [markdown]
# ### The following can be used to find nearest weather station to a fire.

# %%
#This function finds the distance between two points. This method is time consuming as it takes two for loops to find nearest
#weather station to a fire. 
import math
a = np.array((52.5747, -76.52129999999998))
b=np.array((53.625277777777775, -77.70416666666667))
np.linalg.norm(a-b)
# Out:
# 1.5820515852119486

# %%
from geopy.distance import geodesic

# %%
#This function finds the distance between two points in a desired unit. Units can be meter, kilometer, feet and mile. 
def haversine(origin, destination, units='mi'):
    # Radian deltas
    origin_lat = math.radians(float(origin[0]))
    origin_lon = math.radians(float(origin[1]))
    destination_lat = math.radians(float(destination[0]))
    destination_lon = math.radians(float(destination[1]))
    lat_delta = destination_lat - origin_lat
    lon_delta = destination_lon - origin_lon

    # Radius of earth in meters
    r = 6378127

    # Haversine formula
    a = math.sin(lat_delta / 2) ** 2 + math.cos(origin_lat) * \
        math.cos(destination_lat) * math.sin(lon_delta / 2) ** 2
    c = 2 * math.asin(math.sqrt(a))
    meters_traveled = c * r

    scaling_factors = {
        "m:": 1,
        "km": 1 / 1000,
        "ft": 3.2808,  # meters to feet
        "mi:": 0.000621371  # meters to miles
    }

    return meters_traveled * scaling_factors[units]

# %%
haversine(a,b,units = "km")
# Out:
# 141.16155850941186

# %%
#This function gives a customized heatmap. 
def customized_heatmap(df):
    corr_df = df.corr()
# Get only half portion of corr_df to avoid df, so create mask    
    mask = np.triu(np.ones_like(corr_df), k=1)
    
     
    # plot a heatmap of the values
    plt.figure(figsize=(20,14))
    ax = sns.heatmap(corr_df, vmin=-1, vmax=1, cbar=False,
                     cmap='coolwarm', mask=mask, annot=True)
    
    # format the text in the plot to make it easier to read
    for text in ax.texts:
        t = float(text.get_text())
        if -0.25 < t < 0.25:
            text.set_text('')
        else:
            text.set_text(round(t, 2))
        text.set_fontsize('x-large')
    plt.xticks( size='x-large')
    plt.yticks(rotation=0, size='x-large')
    #Save fig uncomment first
#     plt.savefig("Heatmap DF")
    plt.show()

# %%
#Heatmap for weather data.
customized_heatmap(weather_data)

# %%
#Heatmap for wildfire data. 
customized_heatmap(wildfire_QC_2011_L)

# %%
#This figure shows missing values in dataset. Yellow bars indicate missing values. 
plt.figure(figsize=(15,8))
ax =sns.heatmap(wildfire_QC_2011_L.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.show()

# %% [markdown]
# ### As it can be seen from the following figure is that weather data has a lot of missing values. One reason is the nature of the data. Some days are snowing while others are not. Some weather stations prefer to leave it as missing values. Also the columns with flag tag are full of missing values. A value in these kinds of columns mean a special condition about the data. Special conditions are always rare. For more information please refer to https://climate.weather.gc.ca/doc/Technical_Documentation.pdf

# %%
#This figure shows missing values in dataset. Yellow bars indicate missing values. 
plt.figure(figsize=(15,8))
ax =sns.heatmap(weather_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.show()
